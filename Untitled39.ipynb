# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamesaid/IMDB-sentiment-analysis/blob/main/Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !pip install beautifulsoup4
# !pip install textblob
# !pip install mlxtend
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 102.9 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ...

# %%
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# ...
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to /tmp/pip-req-build-a_uujgev
#   Running command git clone --filter=blob:none --quiet https://github.com/laxmimerit/preprocess_kgptalkie.git /tmp/pip-req-build-a_uujgev
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 0f56a6502679f6750b7f0ffed98f590d1f0246bd
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for preprocess_kgptalkie: filename=preprocess_kgptalkie-0.11-py3-none-any.whl size=8174 sha256=9ba9dd75fb832ced600d594ac2b4037b3d63e5a10d2c1cf0ce7fc00675ae462a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pj1oght_/wheels/24/f6/5f/6a2a2252acab6c8ce06a71a210d40e9b744871a9132dbf59bc
# Successfully built preprocess_kgptalkie
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('IMDB Dataset.csv', engine='python', on_bad_lines='skip')

# %%
df.shape
df.columns
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def get_wordcounts(text):
    return len(text.split())

def get_charcounts(text):
    return len(text)

def get_avg_wordlength(text):
    words = text.split()
    return np.mean([len(w) for w in words]) if words else 0

def get_stopwords_counts(text):
    return sum(1 for w in text.split() if w in stop_words)

def remove_html_tags(text):
    return re.sub(r'<.*?>', '', text)

def clean_text(text):

    text = remove_html_tags(text)

    text = text.lower()

    text = text.translate(str.maketrans('', '', string.punctuation))
    return text


df['review'] = df['review'].apply(clean_text)
df['word_counts'] = df['review'].apply(get_wordcounts)
df['char_counts'] = df['review'].apply(get_charcounts)
df['avg_wordlength'] = df['review'].apply(get_avg_wordlength)
df['stopwords_counts'] = df['review'].apply(get_stopwords_counts)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['review_without_stopwords'] = df['review'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
import seaborn as sns
plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
# sns.barplot(x='sentiment', y='word_counts', data=df)
sns.histplot(data=df, x='word_counts', hue='sentiment', kde=True)
plt.title('Word counts')

plt.subplot(2,2,2)
sns.histplot(data=df, x='char_counts', hue='sentiment', kde=True)
plt.title('Char counts')

plt.subplot(2,2,3)
sns.histplot(data=df, x='avg_wordlength', hue='sentiment', kde=True)
plt.title('Avg Word Length')

plt.subplot(2,2,4)
sns.histplot(data=df, x='stopwords_counts', hue='sentiment', kde=True)
plt.title('Stopwords counts')

plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(df['review'],
                                                    df['sentiment'],
                                                    test_size=0.2,
                                                    random_state=0,
                                                    stratify=df['sentiment']
                                                   )

# %%
X_train.shape, X_test.shape
# Out:
# ((8830,), (2208,))

# %%
clf = Pipeline([('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
ypred=clf.predict(X_test)

# %%
print(classification_report(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.87      0.88      1105
#     positive       0.87      0.90      0.88      1103
#
#     accuracy                           0.88      2208
#    macro avg       0.88      0.88      0.88      2208
# weighted avg       0.88      0.88      0.88      2208

# %%
plt.figure(figsize=(8,8))
sns.heatmap(confusion_matrix(y_test, ypred), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# %%
clf.predict(['this is so bad'])
# Out:
# array(['negative'], dtype=object)

# %%
import joblib

joblib.dump(clf, 'sentiment_analysis.pkl')
# Out:
# ['sentiment_analysis.pkl']
